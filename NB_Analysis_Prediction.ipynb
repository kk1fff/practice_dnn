# %%
import numpy
import matplotlib.pyplot as plt
import scipy
import numpy as np
# %matplotlib inline

# %%
import have_people_cnn as model
# Out:
# 100%|██████████| 10000/10000 [2:22:53<00:00,  1.19it/s]
# 0.94777572155
# 0.775193810463

# %%
plt.plot(model.train_acc)
plt.plot(model.test_acc)

# %%
print(model.train.shape)
print(model.test.shape)
def verify(m):
    plt.imshow(m, cmap='Greys_r')
    print(model.y.eval(feed_dict={ model.x: np.reshape(m, [-1, 10000]) }))
verify(model.test[21])
# Out:
# (517, 100, 100)
# (129, 100, 100)
# [[ 0.85875207  0.14124794]]
